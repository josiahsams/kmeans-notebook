% %%
data=load('./lrdata1');

% %%
rndIDX = randperm(size(data,1)); 
data(rndIDX(1:10),:)
% Out:
% ans =
%
%    0.21377   0.48263   0.00000
%    1.23179   1.62783   1.00000
%    1.33528  -0.18496   1.00000
%    0.71111  -0.94921   0.00000
%    1.28175  -0.69474   0.00000
%    0.56499   0.81322   0.00000
%    0.49520   0.65761   0.00000
%   -1.20195   0.11330   0.00000
%    1.94746   0.18587   0.00000
%    2.57501   0.35290   1.00000

% %%
X=data(1:100,1:2);
Y=data(1:100,3);

% %%
size(X)
size(Y)
% Out:
% ans =
%
%    100     2
%
% ans =
%
%    100     1

% %%
pos=find(Y == 1);
neg=find(Y == 0);

% %%
figure; hold on;
plot(X(pos, 1), X(pos, 2), 'k+','LineWidth', 2, 'MarkerSize', 7);
plot(X(neg, 1), X(neg, 2), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 7);
hold off;

% %%
plot_x = [min(X(1:100,1))+1,  max(X(1:100,1))-1]
theta=[-1861.683901928968, 1859.3444461272434, 540.305432943276]

% Calculate the decision boundary line - ??
% y = -(w2/w3)*x - (w1/w3)

plot_y = (-1./theta(3)).*(theta(2).*plot_x + theta(1))

% plot_y = (-1./theta(2)).*(theta(1).*plot_x)
% Out:
% plot_x =
%
%    0.31101   1.47100
%
% theta =
%
%   -1861.68   1859.34    540.31
%
% plot_y =
%
%    2.3753  -1.6165

% %%
figure; hold on;
% figure('Position',[0,600,800,1200]); hold on;
plot(X(pos, 1), X(pos, 2), 'k+','LineWidth', 2, 'MarkerSize', 7);
plot(X(neg, 1), X(neg, 2), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 7);
plot(plot_x, plot_y)
hold off;
