% %%
data=load('./pointsWithIndex');

% %%
rndIDX = randperm(size(data,1)); 
data(rndIDX(1:10),:)
% Out:
% ans =
%
%    639431   588155       15
%    675988   841317        8
%    139212   557713        4
%    211266   534538        4
%    306042    66361        9
%    840100   728839       14
%    659734   844127        8
%    296627    93375        9
%    829673   730398       14
%    284378   223470        9

% %%
X=data(:,1);
Y=data(:,2);
Z=data(:,3);

% %%
size(X)
size(Y)

size(Z)
% Out:
% ans =
%
%    5000      1
%
% ans =
%
%    5000      1
%
% ans =
%
%    5000      1

% %%
c0=find(Z==0);
c1=find(Z==1);
c2=find(Z==2);
c3=find(Z==3);
c4=find(Z==4);
c5=find(Z==5);
c6=find(Z==6);
c7=find(Z==7);
c8=find(Z==8);
c9=find(Z==9);
c10=find(Z==10);
c11=find(Z==11);
c12=find(Z==12);
c13=find(Z==13);
c14=find(Z==14);
c15=find(Z==15);
c16=find(Z==16);
c17=find(Z==17);
c18=find(Z==18);
c19=find(Z==19);

figure; hold on;
plot(X(c0, 1), Y(c0, 1), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 2);
plot(X(c1, 1), Y(c1, 1), 'ko', 'MarkerFaceColor', 'r','MarkerSize', 2);
plot(X(c2, 1), Y(c2, 1), 'ko', 'MarkerFaceColor', 'b','MarkerSize', 2);
plot(X(c3, 1), Y(c3, 1), 'ko', 'MarkerFaceColor', 'm','MarkerSize', 2);
plot(X(c4, 1), Y(c4, 1), 'ko', 'MarkerFaceColor', 'c','MarkerSize', 2);

plot(X(c5, 1), Y(c5, 1), 'ko', 'MarkerFaceColor', 'g','MarkerSize', 2);
plot(X(c6, 1), Y(c6, 1), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 2);
plot(X(c7, 1), Y(c7, 1), 'ko', 'MarkerFaceColor', 'b','MarkerSize', 2);
plot(X(c8, 1), Y(c8, 1), 'ko', 'MarkerFaceColor', 'm','MarkerSize', 2);
plot(X(c9, 1), Y(c9, 1), 'ko', 'MarkerFaceColor', 'c','MarkerSize', 2);

plot(X(c10, 1), Y(c10, 1), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 2);
plot(X(c11, 1), Y(c11, 1), 'ko', 'MarkerFaceColor', 'r','MarkerSize', 2);
plot(X(c12, 1), Y(c12, 1), 'ko', 'MarkerFaceColor', 'b','MarkerSize', 2);
plot(X(c13, 1), Y(c13, 1), 'ko', 'MarkerFaceColor', 'm','MarkerSize', 2);
plot(X(c14, 1), Y(c14, 1), 'ko', 'MarkerFaceColor', 'c','MarkerSize', 2);

plot(X(c15, 1), Y(c15, 1), 'ko', 'MarkerFaceColor', 'g','MarkerSize', 2);
plot(X(c16, 1), Y(c16, 1), 'ko', 'MarkerFaceColor', 'r','MarkerSize', 2);
plot(X(c17, 1), Y(c17, 1), 'ko', 'MarkerFaceColor', 'b','MarkerSize', 2);
plot(X(c18, 1), Y(c18, 1), 'ko', 'MarkerFaceColor', 'm','MarkerSize', 2);
plot(X(c19, 1), Y(c19, 1), 'ko', 'MarkerFaceColor', 'c','MarkerSize', 2);
hold off;

% %%
function[] = fig1(X, Y, CX, CY)
centers=[320602.55 161521.85;
  348806.1106870229 566613.8816793893;
  167856.14071856288 347812.7155688623;
  282254.4871794872 545541.4487179487;
  845835.9801980198 596806.6732673268;
  508062.26420454547 176011.77272727274;
  611588.1314935065 482913.67045454547;
  669604.7718309859 862576.2957746478;
  798491.355140187 321164.04672897194;
  400011.4830508475 404474.99717514124;
  860928.3520599251 532422.6629213484;
  326800.24233128835 818471.6487730062;
  822044.4234527687 734192.0912052117;
  852058.4525993884 157685.52293577982;
  136671.88622754492 558362.8203592814;];
size(centers);
CX = centers(:,1);
CY = centers(:,2);
figure(1); hold on;
plot(X, Y, 'k+','LineWidth', 2, 'MarkerSize', 3);
plot(CX, CY, 'ko', 'MarkerFaceColor', 'y','MarkerSize', 5);
hold off;
end

% %%
function[] = fig2(X, Y, CX, CY)
centers=[ 398498.77142857143 588103.2;
  398555.9485714286 404855.0685714286;
  519976.48728813557 187551.40677966102;
  480581.3025210084 149897.42016806724;
  156461.29090909092 552539.259090909;
  617601.9107142857 399504.21428571426;
  167856.14071856288 347812.7155688623;
  801616.7816455696 321123.3417721519;
  670929.0681818182 862765.7329545454;
  286333.3409090909 153147.61363636365;
  858947.9713467049 546259.659025788;
  341144.24669603526 563300.550660793;
  287645.52777777775 544387.4305555555;
  340928.76470588235 167849.38725490196;
  823421.2507836991 731145.2727272727;
  606574.9562289562 574455.1683501684;
  104435.81666666667 569090.6916666667;
  244654.88563049852 847642.0410557184;
  852058.4525993884 157685.52293577982;
  417799.6942675159 787001.9936305733;];
size(centers);
CX = centers(:,1);
CY = centers(:,2);

figure(1);
hold on;
plot(X, Y, 'k+','LineWidth', 2, 'MarkerSize', 3);
plot(CX, CY, 'ko', 'MarkerFaceColor', 'y','MarkerSize', 5);
hold off;
end

% %%
setenv("GNUTERM","qt")
figure('Position',[0,600,800,1200]);
subplot (2, 1, 1)
fig1(X,Y,CX, CY);
subplot (2, 1, 2)
fig2(X,Y,CX, CY);
